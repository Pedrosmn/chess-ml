# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/processed/rapid/FabianoCaruana_2026-05-26_16-40-39.parquet')

# %%
df.head()
# Out:
#                                                  pgn time_control  \
# 0  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600
# 1  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600
# 2  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600
# 3  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600
# 4  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600
#
#              end_time  rated                        accuracies  \
# 0 2026-03-16 16:18:55   True   {'white': 85.89, 'black': 82.1}
# 1 2026-03-16 16:36:58   True  {'white': 88.43, 'black': 81.83}
# 2 2026-03-16 16:55:50   True  {'white': 90.83, 'black': 95.82}
# 3 2026-03-16 17:23:18   True  {'white': 92.33, 'black': 90.32}
# 4 2026-03-16 17:49:44   True  {'white': 94.83, 'black': 91.98}
#
#                                                  fen time_class  rules  \
# 0           k7/2Q5/8/2P5/1P6/5K1P/5P2/6r1 b - - 4 60      rapid  chess
# ...
