# %%
import pandas as pd

# %%
df = pd.read_json("../data/raw/rapid/1stSecond_2026-05-26_16-30-35.json")

# %%
df.head()
# Out:
#                                             url  \
# 0  https://www.chess.com/game/live/164555416416
# 1  https://www.chess.com/game/live/164557516210
# 2  https://www.chess.com/game/live/164558508584
# 3  https://www.chess.com/game/live/164559494898
# 4  https://www.chess.com/game/live/164560792956
#
#                                                  pgn time_control  \
# 0  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600
# 1  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600
# 2  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600
# 3  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600
# 4  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...          600
#
#              end_time  rated                        accuracies  \
# 0 2026-02-11 19:38:56   True  {'white': 74.33, 'black': 83.67}
# 1 2026-02-11 20:29:00   True   {'white': 91.7, 'black': 80.51}
# 2 2026-02-11 21:01:09   True   {'white': 91.3, 'black': 80.16}
# ...
